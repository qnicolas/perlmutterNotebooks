# %% [markdown]
# # Minimal example

# %%
import numpy as np
import pandas as pd
import dask 
import dask.distributed
import dask.dataframe

# %%
dask.config.config["distributed"]["dashboard"]["link"] = "{JUPYTERHUB_SERVICE_PREFIX}proxy/{port}/status"
from dask.distributed import Client
client=Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37399' processes=16 threads=256, memory=503.15 GiB>

# %%
a=dask.delayed(np.random.random(500000000).reshape((-1,1)))
dd = dask.array.from_delayed(a,shape=(500000000,1),dtype=float)
dd = dd.rechunk((500000000//17, 1))
bins = np.arange(0,1,0.1)
test = dask.array.histogram(dd,bins,weights=dd/500000000)

# %%
# %time test[0].compute()
# Out:
# CPU times: user 1.22 s, sys: 3.56 s, total: 4.78 s
# Wall time: 12.8 s
# array([0.00500096, 0.01500157, 0.02500133, 0.03499379, 0.04499424,
#        0.05499119, 0.06500596, 0.07500627, 0.08500199])

# %%
a=dask.delayed(np.random.random(500000000).reshape((-1,1)))
dd = dask.array.from_array(a,chunks=(500000000//17, 1))
bins = np.arange(0,1,0.1)
test = dask.array.histogram(dd,bins,weights=dd/500000000)

# %%
# %time test[0].compute()
# Out:
# CPU times: user 1.22 s, sys: 3.56 s, total: 4.78 s
# Wall time: 12.8 s
# array([0.00500096, 0.01500157, 0.02500133, 0.03499379, 0.04499424,
#        0.05499119, 0.06500596, 0.07500627, 0.08500199])

# %%
a=np.random.random(500000000)
dd = dask.dataframe.from_array(a.reshape((-1,1)), chunksize=len(a)//20, columns=('a',))
bins = np.arange(0,1,0.1)
blBinner = dd['a'].map_partitions(pd.cut, bins)
count = dd['a'].groupby([blBinner]).count()

# %%
# %time count.compute()

# %%
# %time count.compute(scheduler='single-threaded')
# Out:
# /global/common/software/m3310/xrdask2022.11.qn/lib/python3.10/site-packages/dask/base.py:1368: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# CPU times: user 16.2 s, sys: 5.08 s, total: 21.3 s
# Wall time: 19.4 s
# a
# (0.0, 0.1]    50018407
# (0.1, 0.2]    50008261
# (0.2, 0.3]    49994805
# (0.3, 0.4]    50001118
# (0.4, 0.5]    49996264
# (0.5, 0.6]    50008640
# (0.6, 0.7]    49996476
# (0.7, 0.8]    49986329
# (0.8, 0.9]    49997573
# Name: a, dtype: int64

# %% [markdown]
# # The rest

# %%
import os
import glob
import time

import pandas as pd
import numpy as np
import xarray as xr
import datetime

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import NullFormatter
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

import cartopy.crs as ccrs
import cartopy

import sys
p = os.path.abspath('../')
if p not in sys.path:
    sys.path.append(p)

from orographicPrecipitation.wrfProcessing.wrf_hr_utils import *
from orographicPrecipitation.wrfProcessing.wrfProcessing import *


from orographicPrecipitation.precip_model_functions import qsat,humidsat
from orographicConvectionTheory.orographicConvectionTheory import *
SCRATCH='/global/cscratch1/sd/qnicolas/'

import metpy.calc as mpcalc
from metpy.plots import SkewT
from metpy.units import units

# %%
xr.set_options(display_style='text')

# %% [markdown]
# # P-$B_L$ scatterplots

# %%
class Simulation():
    def __init__(self,path,center,dx,data_type='wrfout',suffix='days1-200'):
        self.center = center
        self.dx = dx
        self.path=path
        self.input = xr.open_dataset(path+'wrfinput_d01')
        #self.QLDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.QLDEEP_HOURLY.%s.nc'%suffix)
        #self.TLDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.TLDEEP_HOURLY.%s.nc'%suffix)
        #self.THETAEBDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.THETAEBDEEP_HOURLY.%s.nc'%suffix)
        #self.BLSIMPLEDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.BLSIMPLEDEEP_HOURLY.%s.nc'%suffix)
        self.RAINNCV_HOURLY = xr.open_dataarray(self.path +'diags/wrf.RAINNCV_HOURLY.%s.nc'%suffix)
        
        #self.THETAELDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.THETAELDEEP_HOURLY.%s.nc'%suffix)
        #self.THETAELSTARDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.THETAELSTARDEEP_HOURLY.%s.nc'%suffix)
        self.BLDEEP_HOURLY = xr.open_dataarray(self.path +'diags/wrf.BLDEEP_HOURLY.%s.nc'%suffix)
        
        #if data_type=='wrfout':
        #    self.data = extract_wrfout(path)
        #elif data_type=='wrfsub':
        #    self.data = extract_wrfsub(path)
        #else:
        #    raise ValueError('data_type')
        
W10S300 = Simulation('/pscratch/sd/q/qnicolas/wrfdata/channel.wrf.100x2.mountain.60lev.500m.3km/',1635,3)
W12S300 = Simulation('/pscratch/sd/q/qnicolas/wrfdata/channel.wrf.100x2.mountain.60lev.500m.12mps.3km/',1635,3,suffix='0531-0730')
W10S296 = Simulation('/pscratch/sd/q/qnicolas/wrfdata/channel.wrf.100x2.mountain.60lev.500m.296K.3km/',1635,3,suffix='0531-0730')

# %%
W10S300.label="10m/s, 300K"
W12S300.label="12m/s, 300K"
W10S296.label="10m/s, 296K"

# %% [markdown]
# ## Analysis

# %%
def get_bins(var,nbins):
    var_sorted = sorted(np.array(var).reshape(-1))
    quantiles=np.linspace(0.,len(var)-1,nbins+1)
    bins = [var_sorted[int(i)]  for i in quantiles]
    bin_centers = [np.mean(var_sorted[int(quantiles[i]):int(quantiles[i+1])]) for i in range(len(quantiles)-1)]
    return np.array(bins)#,np.array(bin_centers)

def select_bootstrap_sample(distribution):
    n=len(distribution)
    return distribution[np.random.randint(0,n,size=n)]
def bootstrap_CI_mean(data,CI_level,nsamples=100):
    """Compute a confidence interval for the mean of a et of data at the level CI_level (0<CI_level<100), using nsamples bootstrap samples"""
    means = np.zeros(nsamples)
    for i in range(nsamples):
        means[i]=select_bootstrap_sample(data).mean()
    return [np.percentile(means,50-CI_level/2),np.percentile(means,50+CI_level/2)]

def get_binned(a,b,bins,itq=False,bootstrap=False):
    idx_bin_inf = max(0,np.argmax(bins>float(a.min()))-1)
    idx_bin_sup = np.argmin(bins<float(a.max()))
    if idx_bin_sup==0 or idx_bin_sup==len(bins)-1:
        bins=bins[idx_bin_inf:]
    else:
        bins=bins[idx_bin_inf:idx_bin_sup+1]
    bin_centers=(bins[1:]+bins[:-1])/2
    digitized = np.digitize(np.array(a), bins)
    bin_means = np.array([np.array(b)[digitized == i].mean() for i in range(1, len(bins))])
    if itq:
        bin_median = np.array([np.median(np.array(b)[digitized == i]) for i in range(1, len(bins))])
        try:
            bin_q1 = np.array([np.quantile(np.array(b)[digitized == i],0.25) for i in range(1, len(bins))])
            bin_q2 = np.array([np.quantile(np.array(b)[digitized == i],0.75) for i in range(1, len(bins))])
        except IndexError:
            bin_q1 = bin_median
            bin_q2 = bin_median
        return bin_centers,bin_means,bin_median,bin_q1,bin_q2
    elif bootstrap :
        cinf_csup =  np.array([bootstrap_CI_mean(np.array(b)[digitized == i],95) for i in range(1, len(bins))])
        return bin_centers,bin_means,cinf_csup[:,0],cinf_csup[:,1]
    else:
        return bin_centers,bin_means

def get_count(a,bins):
    idx_bin_inf = max(0,np.argmax(bins>float(a.min()))-1)
    idx_bin_sup = np.argmin(bins<float(a.max()))
    if idx_bin_sup==0 or idx_bin_sup==len(bins)-1:
        bins=bins[idx_bin_inf:]
    else:
        bins=bins[idx_bin_inf:idx_bin_sup+1]
    bin_centers=(bins[1:]+bins[:-1])/2
    count = np.histogram(a,bins)[0]
    return bin_centers,count

def get_binned_dask(a,b,bins,ntasks=16):
    idx_bin_inf = max(0,np.argmax(bins>float(a.min()))-1)
    idx_bin_sup = np.argmin(bins<float(a.max()))
    if idx_bin_sup==0 or idx_bin_sup==len(bins)-1:
        bins=bins[idx_bin_inf:]
    else:
        bins=bins[idx_bin_inf:idx_bin_sup+1]
    bin_centers=(bins[1:]+bins[:-1])/2
    
    dd = dask.dataframe.from_array(np.array([a,b]).transpose(), chunksize=len(a)//ntasks+1, columns=('a','b'))
    blBinner = dd['a'].map_partitions(pd.cut, bins)
    bin_means = np.array(dd['b'].groupby([blBinner]).mean().compute(scheduler='single-threaded'))
    return bin_centers,bin_means


def get_count_dask(a,bins,ntasks=16):
    idx_bin_inf = max(0,np.argmax(bins>float(a.min()))-1)
    idx_bin_sup = np.argmin(bins<float(a.max()))
    if idx_bin_sup==0 or idx_bin_sup==len(bins)-1:
        bins=bins[idx_bin_inf:]
    else:
        bins=bins[idx_bin_inf:idx_bin_sup+1]
    bin_centers=(bins[1:]+bins[:-1])/2
    
    dd = dask.dataframe.from_array(a.reshape((-1,1)), chunksize=len(a)//ntasks+1, columns=('a',))
    blBinner = dd['a'].map_partitions(pd.cut, bins)
    count = np.array(dd['a'].groupby([blBinner]).count().compute(scheduler='single-threaded'))
    return bin_centers,count

# %%
import dask;import dask.dataframe
dask.config.config["distributed"]["dashboard"]["link"] = "{JUPYTERHUB_SERVICE_PREFIX}proxy/{port}/status"
from dask.distributed import Client
client=Client()#n_workers=16,memory_limit="35GB",processes=False)
client
# Out:
# <Client: 'tcp://127.0.0.1:46613' processes=16 threads=256, memory=540.25 GB>

# %%
a = np.array(W10S296.BLDEEP_HOURLY[-1000:]).reshape(-1)
b = np.array(W10S296.RAINNCV_HOURLY[-1000:]).reshape(-1)

bins = np.linspace(-1,0.2,101)
ntasks=16
dd = dask.dataframe.from_array(a.reshape((-1,1)), chunksize=len(a)//ntasks+1, columns=('a',))

dd

blBinner = dd['a'].map_partitions(pd.cut, bins)

test = dd['a'].groupby([blBinner]).count()

# %%
# %time test.compute()
# Out:
# CPU times: user 9.63 s, sys: 31.2 s, total: 40.8 s
# Wall time: 42.2 s
# a
# (-1.0, -0.988]        0
# (-0.988, -0.976]      0
# (-0.976, -0.964]      0
# (-0.964, -0.952]      0
# (-0.952, -0.94]       0
#                    ...
# (0.14, 0.152]       335
# (0.152, 0.164]       57
# (0.164, 0.176]        7
# (0.176, 0.188]        4
# (0.188, 0.2]          0
# Name: a, Length: 100, dtype: int64

# %%
# %%time
_,ax=plt.subplots(figsize=(10,4))
bins = np.linspace(-1,0.2,101)
for Sim in (W10S300,W10S296,):
    centers,means = get_binned_dask(np.array(Sim.BLDEEP_HOURLY[-1488:]).reshape(-1),np.array(Sim.RAINNCV_HOURLY[-1488:]).reshape(-1),bins,ntasks=16*2)
    ax.plot(centers,means,label=Sim.label)
# Out:
# CPU times: user 25 s, sys: 14.2 s, total: 39.2 s
# Wall time: 39.2 s

# %%
# %%time
_,ax=plt.subplots(figsize=(10,4))
bins = np.linspace(-1,0.2,101)
for Sim in (W10S300,W10S296):
    centers,means = get_binned_dask(np.array(Sim.BLDEEP_HOURLY[-1488:]).reshape(-1),np.array(Sim.RAINNCV_HOURLY[-1488:]).reshape(-1),bins,ntasks=16*2)
    ax.plot(centers,means,label=Sim.label)
# Out:
# CPU times: user 31.5 s, sys: 55.7 s, total: 1min 27s
# Wall time: 14.9 s

# %%
# %%time
_,ax=plt.subplots(figsize=(10,4))
bins = np.linspace(-1,0.2,101)
for Sim in (W10S300,W10S296):
    centers,count = get_count_dask(np.array(Sim.BLDEEP_HOURLY[-1488:]).reshape(-1),bins,ntasks=16*2)
    ax.plot(centers,count,label=Sim.label)
    ax.set_yscale('log')
# Out:
# CPU times: user 48.9 s, sys: 36.1 s, total: 1min 25s
# Wall time: 11.8 s

# %%
# %%time
_,ax=plt.subplots(figsize=(10,4))
bins = np.linspace(-1,0.1,101)
for Sim in (W10S300,W10S296):
    centers,means = get_binned_dask(np.array(Sim.BLDEEP_HOURLY[-1488:]).reshape(-1),np.array(Sim.RAINNCV_HOURLY[-1488:]).reshape(-1),bins,ntasks=16*2)
    ax.plot(centers,means,label=Sim.label)
# Out:
# CPU times: user 32.4 s, sys: 57.6 s, total: 1min 29s
# Wall time: 14.4 s
